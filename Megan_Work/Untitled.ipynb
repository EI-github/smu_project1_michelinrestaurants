# %%
import requests
import json
from pprint import pprint
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Import cleaned csv
cleandata = "../Resources/Cleaned.csv"

df = pd.read_csv(cleandata)
df.head(25)
# Out:
#     Unnamed: 0                     name  year   latitude   longitude  \
# 0            0             Kilian Stuba  2019  47.348580   10.171140
# 1            1            Pfefferschiff  2019  47.837870   13.079170
# 2            2                Esszimmer  2019  47.806850   13.034090
# 3            3               Carpe Diem  2019  47.800010   13.040060
# 4            4                   Edvard  2019  48.216503   16.368520
# 5            5                 Das Loft  2019  48.212720   16.379310
# 6            6       Pramerl & the Wolf  2019  48.209450   16.371740
# 7            7             Walter Bauer  2019  48.209230   16.376720
# 8            8                    SHIKI  2019  48.204067   16.370980
# 9            9                     Tian  2019  48.205130   16.374560
# 10          10                     aend  2019  48.189570   16.341150
# 11          11  Le Ciel by Toni Mörwald  2019  48.202090   16.371560
# 12          12                  Chez TJ  2019  37.394680 -122.080440
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'name', 'year', 'latitude', 'longitude', 'city', 'region',
#        'zipCode', 'cuisine', 'price', 'url', 'Michelin Star Count'],
#       dtype='object')

# %% [markdown]
# df.columns= ["Number", 'name', 'year', 'latitude', 'longitude', 'city', 'region',
#        'zipCode', 'cuisine', 'price', 'url', 'Michelin Star Count'
